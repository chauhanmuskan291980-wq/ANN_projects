# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X = np.array([[1],[2],[3],[4]])
y = np.array([25,30,40,50])

model = LinearRegression()
model.fit(X,y)

prediction = model.predict([[5]])

print("Prediction for 5:", prediction)
# Predict line value
y_pred = model.predict(X)

# Plot original points 
plt.scatter(X,y,label = "Actual Data")

# Plot training line
plt.plot(X,y_pred,label = "Regression Line")


# Labels
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression")

# Show Legend
plt.legend()

# Show Graph
plt.show()
# Out:
# Prediction for 5: [57.5]

# %%
from sklearn.metrics import r2_score

actual = [3,5,7,9]
predicted = [2.8,5.2,6.9,9.1]

score = r2_score(actual, predicted)

print(score)
# Out:
# 0.995

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression

X = np.array([
    [1000,2],
    [1200,3],
    [1500,4]
])

y = np.array([20,25,35])

model = LinearRegression()
model.fit(X,y)

print(model.predict([[1300,3]]))
print(model.predict([[1400,5]]))
# Out:
# [30.]
# [25.]

# %%
import numpy as np 
import matplotlib.pyplot as plt
errors = np.random.normal(0,1,100)
plt.hist(errors)
plt.show()
